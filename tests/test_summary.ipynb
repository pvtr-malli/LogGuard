# %% [markdown]
# ================================================================================
# LATENCY TEST SUMMARY
# ================================================================================
#
# Total Tests: 50
# Successful: 50
# Failed: 0
#
# Metric                         Mean       Median     P95        P99        Min        Max
# ------------------------------------------------------------------------------------------
# Kafka → Detection (ms)         14760.5    15049.1    15055.5    15064.1    3537.4     15071.4
# Total Latency (ms)             14760.5    15049.1    15055.5    15064.1    3537.4     15071.4
# Total Latency (seconds)        14.76      15.05      15.06      15.06      3.54       15.07
#
# ================================================================================
# REQUIREMENTS CHECK
# ================================================================================
# Requirement: < 30 seconds detection + window overhead
# Acceptance Criteria: < 33.0 seconds (30s window + 3s processing)
#
# Latency Metrics:
#   • Average Latency: 14.76 seconds
#   • P95 Latency: 15.06 seconds
#   • P99 Latency: 15.06 seconds
#
# Status:
#   • Average: ✓ PASSED (14.76s < 33.0s)
#   • P95:     ✓ PASSED (15.06s < 33.0s)
#   • P99:     ✓ PASSED (15.06s < 33.0s)
#
# Overall: ✓ ALL CHECKS PASSEDs
# ================================================================================
